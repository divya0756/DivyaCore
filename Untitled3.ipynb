# %%
def greet():
    print("Hello, world!")
greet()
# Out:
# Hello, world!

# %%
def dev():
    print("kingdom")
dev()
# Out:
# kingdom

# %%
def greet(name):
    print(f"Hello, {name}")
greet("Dibya")
# Out:
# Hello, Dibya

# %%
def greet(name):
    print(f"Hello,{name}")
greet("Sita")
# Out:
# Hello,Sita

# %%
def app(name):
    print(f"{name}")
app("Ishwor Lahurey")
# Out:
# Ishwor Lahurey

# %%
def add(a, b):
    return a + b

result = add(5, 7)
print(result)
# Out:
# 12

# %% [markdown]
# def greet():
#     print("Hello, world!")
#     greet()
#
# greet()

# %%
def greet():
    print("Hello, world!")
    greet()

greet()
# Out:
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# ...

# %%
print("Hi Divya")
# Out:
# Hi Divya
